# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
titanic = pd.read_csv('./titanic.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titanic.shape
# Out:
# (418, 11)

# %% [markdown]
# ## 1. 결측치 대체 및 제거

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic_1 = titanic.drop(['Cabin'], axis=1)
titanic_1 = titanic_1.fillna(titanic_1.mean())

# %%
titanic_1.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## 2. 지표변수

# %%
titanic_1['Age']
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
oldness = []
for a in titanic_1['Age']:
    if (10 <= a <= 30):
        oldness.append('young')
    elif (31 <= a <= 50):
        oldness.append('middle')
    else:
        oldness.append('old')

titanic_1['oldness'] = oldness

titanic_1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked oldness
# 0  34.5      0      0   330911   7.8292        Q  middle
# 1  47.0      1      0   363272   7.0000        S  middle
# 2  62.0      0      0   240276   9.6875        Q     old
# 3  27.0      0      0   315154   8.6625        S   young
# 4  22.0      1      1  3101298  12.2875        S   young

# %% [markdown]
# ## 3. Feature Split

# %%
titanic['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
first_name = []
last_name = []
for name in titanic['Name']:
    name = name.replace(',', '.')
    names = name.split('.')
    first_name.append(names[0])
    last_name.append(names[2][1:])
titanic['First name'] = first_name
titanic['Last name'] = last_name
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked First name  \
# 0  34.5      0      0   330911   7.8292   NaN        Q      Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S     Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q      Myles
# 3  27.0      0      0   315154   8.6625   NaN        S       Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S   Hirvonen
#
#                        Last name
# 0                          James
# 1            James (Ellen Needs)
# 2                 Thomas Francis
# 3                         Albert
# 4  Alexander (Helga E Lindqvist)

# %% [markdown]
# ## 4. Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
mm_scaler = MinMaxScaler()
sd_scaler = StandardScaler()

# %%
# Min max Scaling
mm_scaler = mm_scaler.fit_transform(titanic_1['Age'].values.reshape(-1,1))
titanic_1['Min max scaled age'] = mm_scaler

# %%
# Standard Scaling
sd_scaler = sd_scaler.fit_transform(titanic_1['Age'].values.reshape(-1,1))
titanic_1['Standard scaled age'] = sd_scaler

# %%
titanic_1.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked oldness  Min max sclaed age  \
# 0  34.5      0      0   330911   7.8292        Q  middle            0.452723
# 1  47.0      1      0   363272   7.0000        S  middle            0.617566
# 2  62.0      0      0   240276   9.6875        Q     old            0.815377
# 3  27.0      0      0   315154   8.6625        S   young            0.353818
# 4  22.0      1      1  3101298  12.2875        S   young            0.287881
#
#    Standard scaled age
# 0             0.334993
# 1             1.325530
# 2             2.514175
# 3            -0.259330
# 4            -0.655545

# %% [markdown]
# ## 5. One-hot encoding

# %%
sex_encoded = []
for sex in titanic['Sex']:
    if sex == 'male':
        sex_encoded.append(1)
    else:
        sex_encoded.append(0)
titanic['Sex'] = sex_encoded
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked First name  \
# 0  34.5      0      0   330911   7.8292   NaN        Q      Kelly
# 1  47.0      1      0   363272   7.0000   NaN        S     Wilkes
# 2  62.0      0      0   240276   9.6875   NaN        Q      Myles
# 3  27.0      0      0   315154   8.6625   NaN        S       Wirz
# 4  22.0      1      1  3101298  12.2875   NaN        S   Hirvonen
#
#                        Last name
# 0                          James
# 1            James (Ellen Needs)
# 2                 Thomas Francis
# 3                         Albert
# 4  Alexander (Helga E Lindqvist)
